# %%
# %load_ext autoreload
# %autoreload 2

# %%
from nn import CallerEmpirical
import torch
from decoder import GreedyCTCDecoder
import os
from ont_fast5_api.fast5_interface import get_fast5_file
from tqdm import tqdm
from sklearn.preprocessing import normalize
from torch.nn.utils.rnn import pad_sequence
from utils import sort_transcript, get_motifs_identified
import pandas as pd
from output import save_inference_to_csv

# %%
n_classes = 19
hidden_size = 256
model_path = 'model.pth'
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
#device = torch.device('cpu')

# Initialising decoder
greedy_decoder = GreedyCTCDecoder(n_classes=19)

# %%
model = CallerEmpirical(num_classes=n_classes, hidden_dim=hidden_size)
    
# Loading model from checkpoint
if device == torch.device('cpu'):
    checkpoint = torch.load(model_path, map_location=torch.device('cpu'))
else:
    checkpoint = torch.load(model_path)
    
model.load_state_dict(checkpoint['model_state_dict'])

model = model.to(device)

# %%
# read a fast5 file in
# decide whether to store squiggles in memory or offload
# feed into the model 8 at a time and collect the predictions
# output as a csv - dataframe

# %%
def extract_fast5_data_from_file(fast5_filepath):
    squiggles = {}
    with get_fast5_file(fast5_filepath, mode="r") as f5:
            read_ids = f5.get_read_ids()

            for read_id in read_ids:
                read = f5.get_read(read_id)
                squiggle = read.get_raw_data()
                squiggles[read_id] = squiggle

    return squiggles


def extract_fast5_data_from_folder(fast5_path, target_read_ids):

    total_files = len(os.listdir(fast5_path))
    squiggles = {}

    for file in tqdm(os.listdir(fast5_path), total=total_files):

        filepath = os.path.join(fast5_path, file)
        with get_fast5_file(filepath, mode="r") as f5:

            read_ids = f5.get_read_ids()

            for read_id in read_ids:
                read = f5.get_read(read_id)
                squiggle = read.get_raw_data()
                squiggles[read_id] = squiggle

    return squiggles

# %%
def model_inference(data_arr, read_ids, model, device, greedy_decoder) :

    greedy_transcripts_arr = []
    sorted_greedy_transcripts = []
    read_ids_arr = []

    n_training_samples = len(data_arr)

    print(f"Evaluation {n_training_samples} data points")

    batch_size = 8
    model = model.to(device)

    with torch.no_grad():
        for ind in tqdm(range(0, n_training_samples, batch_size)):

            if n_training_samples - ind < batch_size:
                # Add random seqs to the end and get an output still
                continue
            
            input_seqs = [
                normalize([data_arr[k]], norm='max').flatten() for k in range(ind, ind + batch_size)]
            
            read_ids_arr.extend(read_ids[ind: ind + batch_size])

            input_seqs = pad_sequence([torch.tensor(
                        i, dtype=torch.float32) for i in input_seqs], batch_first=True)
            
            input_seqs = input_seqs.view(input_seqs.shape[0], 1, input_seqs.shape[1])
            input_seqs = input_seqs.to(device)

            model_output = model(input_seqs)
            
            # If on GPU - detach
            if device.type == 'cuda':
                model_output = model_output.cpu()
            
            for k in range(batch_size):
                greedy_result = greedy_decoder(model_output[k])
                greedy_transcript = " ".join(greedy_result)
                sorted_greedy = sort_transcript(greedy_transcript)
                greedy_transcripts_arr.append(greedy_transcript)
                sorted_greedy_transcripts.append(sorted_greedy)
            torch.cuda.empty_cache()
            
           
    return sorted_greedy_transcripts, greedy_transcripts_arr, read_ids_arr

# %%
/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  75%|███████▌  | 375/500 [01:01<00:20,  6.22it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  76%|███████▌  | 379/500 [01:02<00:20,  5.94it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  76%|███████▌  | 381/500 [01:02<00:19,  6.21it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  79%|███████▉  | 395/500 [01:06<00:13,  7.86it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  80%|████████  | 400/500 [01:07<00:12,  7.80it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  81%|████████▏ | 407/500 [01:08<00:16,  5.68it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  82%|████████▏ | 409/500 [01:08<00:12,  7.09it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  82%|████████▏ | 412/500 [01:08<00:11,  7.70it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  84%|████████▍ | 422/500 [01:10<00:11,  6.84it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  86%|████████▌ | 430/500 [01:11<00:09,  7.22it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  87%|████████▋ | 436/500 [01:11<00:08,  7.39it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  88%|████████▊ | 438/500 [01:12<00:12,  4.95it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  91%|█████████ | 455/500 [01:14<00:04,  9.13it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  95%|█████████▍| 474/500 [01:16<00:03,  7.23it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  95%|█████████▌| 476/500 [01:17<00:03,  7.48it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  98%|█████████▊| 489/500 [01:20<00:02,  3.83it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
#  99%|█████████▊| 493/500 [01:21<00:01,  4.75it/s]c:\Users\Parv\anaconda3\envs\pytorch_gpu\Lib\site-packages\torch\nn\modules\conv.py:306: UserWarning: Plan failed with a cudnnException: CUDNN_BACKEND_EXECUTION_PLAN_DESCRIPTOR: cudnnFinalize Descriptor Failed cudnn_status: CUDNN_STATUS_NOT_SUPPORTED (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\cudnn\Conv_v8.cpp:919.)
#   return F.conv1d(input, weight, bias, self.stride,
# 100%|██████████| 500/500 [01:22<00:00,  6.04it/s]

# %%
sorted = [[list(set(i)) for i in j] for j in sorted_greedy]

# %%
sorted = [sort_transcript(i, payload=True) for i in greedy_transcripts[:10]]

# %%
[get_motifs_identified(i) for i in sorted]
# Out:
# [['ltm8_5x8', 'ltm8_5x3', 'ltm8_6x3'],
#  ['ltm8_3x1', 'ltm8_5x8', 'ltm8_6x8', 'ltm8_9x8'],
#  ['ltm8_1x5', 'ltm8_4x2'],
#  ['ltm8_1x2', 'ltm8_2x4', 'ltm8_7x2', 'ltm8_10x2'],
#  ['ltm8_1x3', 'ltm8_9x1'],
#  ['ltm8_1x1', 'ltm8_6x2'],
#  ['ltm8_1x4', 'ltm8_2x4', 'ltm8_3x1', 'ltm8_7x1', 'ltm8_10x2'],
#  ['ltm8_1x1', 'ltm8_2x4', 'ltm8_7x2', 'ltm8_8x2', 'ltm8_9x1', 'ltm8_10x2'],
#  ['ltm8_1x8', 'ltm8_2x2', 'ltm8_4x7', 'ltm8_5x7', 'ltm8_6x6'],
#  ['ltm8_4x2', 'ltm8_7x2', 'ltm8_9x6', 'ltm8_10x8']]

# %%
# motif design sequence prediction basically, similar to the way do it in motif search

# ltm8_1x8 ---- ltm8_10x8 from 9 to 18

# %%
fast5_filepath
# Out:
# 'F:\\HelixWorks\\Basecalling\\data\\motifcaller_2024-10-07_07-49\\FAST5\\FAV28773_cc4a0239_36c6ee2e_4.fast5'

# %%
os.path.basename(fast5_filepath)
# Out:
# 'FAV28773_cc4a0239_36c6ee2e_4.fast5'

# %%
save_inference_to_csv(sorted_greedy_transcripts=sorted_greedy, greedy_transcripts_arr=greedy_transcripts, read_ids_arr=read_ids_arr, savepath='', fast5_filepath=fast5_filepath)
# Out:
# Output file saved to caller_inference_FAV28773_cc4a0239_36c6ee2e_4_5f3c1571-2b5e-4243-93e6-cf457d25b6c3.csv
