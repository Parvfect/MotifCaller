# %%
import pandas as pd

test_df = pd.read_pickle('sampled_test_dataset_v4_spacers.pkl')

test_df.head()
# Out:
#        ONT_Barcode                     HW_Address  \
# 17549            5  barcode_external01_internal08
# 62207           53  barcode_external07_internal06
# 68815           53  barcode_external04_internal08
# 2132             5  barcode_external06_internal01
# 69109           53  barcode_external05_internal08
#
#                                                  Payload  \
# 17549  [[2, 4, 6, 8], [2, 3, 4, 8], [2, 3, 7, 8], [1,...
# 62207  [[2, 3, 5, 7], [2, 4, 6, 7], [2, 5, 6, 8], [1,...
# 68815  [[1, 2, 3, 8], [1, 3, 4, 7], [3, 5, 6, 8], [4,...
# 2132   [[3, 4, 6, 8], [4, 6, 7, 8], [2, 5, 6, 7], [1,...
# 69109  [[2, 6, 7, 8], [1, 3, 4, 7], [1, 3, 6, 8], [1,...
#
#                                   Library_Motifs  \
# 17549  [ltm8_2x8, ltm8_6x1, ltm8_8x3, ltm8_10x7]
# 62207  [ltm8_3x3, ltm8_5x5, ltm8_6x5, ltm8_10x6]
# 68815             [ltm8_6x6, ltm8_7x2, ltm8_8x4]
# 2132                        [ltm8_5x1, ltm8_6x6]
# 69109                                 [ltm8_1x5]
#
# ...
